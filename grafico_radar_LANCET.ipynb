# %% [markdown]
# <a href="https://colab.research.google.com/github/gabriel-masson/Chika_2025.1/blob/main/grafico_radar_LANCET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introduction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# New data for the "Without PAHO recommendation" chart
data_without_paho = {
    "Metric": ["Accuracy", "Recall", "Especificity", "Precision", "F1_score", "AUC"],
    "DecisionTree": [66.35, 86.79, 45.1, 62.16, 72.44, 65.95],
    "RandomForest": [66.35, 67.92, 64.71, 66.67, 67.29, 66.32],
    "SVC": [56.73, 56.6, 56.86, 57.69, 57.14, 56.73],
    "XGBoost": [53.85, 58.49, 49.02, 54.39, 56.36, 53.76],
    "AdaBoost": [52.88, 49.06, 56.86, 54.17, 51.49, 52.96],
    "GradientBoost": [58.65, 54.72, 62.75, 60.42, 57.43, 58.73]
}

# Cores correspondentes a cada modelo
model_colors = {
    "DecisionTree": "#72B6A1",
    "RandomForest": "#E99675",
    "SVC": "#95A3C3",
    "XGBoost": "#DB96C0",
    "AdaBoost": "#A2C865",
    "GradientBoost": "#E5C949"
}

df = pd.DataFrame(data_without_paho)
labels = df["Metric"].values
num_vars = len(labels)

angles2 = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
angles2 += angles2[:1]

fig, ax = plt.subplots(figsize=(10, 8), subplot_kw=dict(polar=True))

# Add each model to the graph with the corresponding color
for model in df.columns[1:]:
    values = df[model].values.tolist()
    values += values[:1]
    ax.plot(angles2, values, label=model, color=model_colors[model], linewidth=2)

fig.suptitle("Model Performance Comparison", fontsize=16)
ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)
ax.set_thetagrids(np.degrees(angles2[:-1]), labels)
ax.set_ylim(0, 100)
plt.legend(loc='upper right', bbox_to_anchor=(1.3, 1.1))
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# New data for the "Without PAHO recommendation" chart
data_without_paho = {
    "Metric": ["Accuracy", "Recall", "Especificity", "Precision", "F1_score", "AUC"],
    "DecisionTree": [57.69, 71.7, 43.14, 56.72, 63.33, 57.42],
    "RandomForest": [62.5, 60.38, 64.71, 64.0, 62.14, 62.54],
    "SVC": [55.77, 69.81, 41.18, 55.22, 61.67, 55.49],
    "XGBoost": [59.62, 62.26, 56.86, 60.0, 61.11, 59.56],
    "AdaBoost": [59.62, 60.38, 58.82, 60.38, 60.38, 59.6],
    "GradientBoost": [52.88, 45.28, 60.78, 54.55, 49.48, 53.03]
}

# Cores correspondentes
model_colors = {
    "DecisionTree": "#72B6A1",
    "RandomForest": "#E99675",
    "SVC": "#95A3C3",
    "XGBoost": "#DB96C0",
    "AdaBoost": "#A2C865",
    "GradientBoost": "#E5C949"
}

df2 = pd.DataFrame(data_without_paho)
labels = df2["Metric"].values
num_vars = len(labels)

# Angles for the radar chart
angles2 = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
angles2 += angles2[:1]

fig, ax = plt.subplots(figsize=(10, 8), subplot_kw=dict(polar=True))

# Add each model to the graph with the correct colors
for model in df2.columns[1:]:
    values = df2[model].values.tolist()
    values += values[:1]
    ax.plot(angles2, values, label=model, color=model_colors[model], linewidth=2)

fig.suptitle("Model Performance Pain Points", fontsize=16)
ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)
ax.set_thetagrids(np.degrees(angles2[:-1]), labels)
ax.set_ylim(0, 100)
plt.legend(loc='upper right', bbox_to_anchor=(1.3, 1.1))
plt.tight_layout()

plt.show()
